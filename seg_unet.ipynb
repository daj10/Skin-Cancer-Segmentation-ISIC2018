# %% [markdown]
# <a href="https://colab.research.google.com/github/daj10/Skin-Cancer-Segmentation-ISIC2018/blob/main/seg_unet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Skin Cancer Segmentation:** ***Melanoma Detection***
#
# > Task 1: Lesion Segmentation, featuring image contour detection
#
# > Task 2: Lesion Attribute Detection, featuring semantic image segmentation
#
#
# [Data source: ISIC 2018](https://challenge.isic-archive.com/data#2018)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/'My Drive'/Reconnaissance_Formes
# Out:
# /content/drive/My Drive/Reconnaissance_Formes

# %% [markdown]
# ## **Import Librairies**

# %%
import sys
import os
import cv2
import time
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from glob import glob
import skimage.io as io
from skimage import exposure
import skimage.transform as trans
from scipy import ndimage
from scipy import misc
from sklearn.model_selection import train_test_split
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
from keras import backend as keras
#for group normalization
sys.path.append('/content/drive/MyDrive/Reconnaissance_Formes/Keras-Group-Normalization-master') 
from group_norm import GroupNormalization

# %% [markdown]
# ## **Data Pre-processing**
#
# > store numpy array of images

# %% [markdown]
# ### Training Data

# %%
IMAGES = glob('/content/drive/MyDrive/Reconnaissance_Formes/ISIC2018/Train/images/*.jpg') #directory of original images
MASKS = glob('/content/drive/MyDrive/Reconnaissance_Formes/ISIC2018/Train/masks/*.png') #directory of mask images

# %%
# Test if every images have its mask
i = 0
t1 = time.time()
for elt, elt2 in zip(sorted(IMAGES), sorted(MASKS)):
    if (os.path.splitext(os.path.split(elt)[1])[0]).split("_")[1] == (os.path.splitext(os.path.split(elt2)[1])[0]).split("_")[1]:
      i+=1
print(i)
t2 = time.time()
t = t2 - t1
print("excecution time:", t)
print(sorted(IMAGES)[1000])
print(sorted(MASKS)[1000])
# Out:
# 1500
# excecution time: 0.007791757583618164
# /content/drive/MyDrive/Reconnaissance_Formes/ISIC2018/Train/images/ISIC_0010847.jpg
# /content/drive/MyDrive/Reconnaissance_Formes/ISIC2018/Train/masks/ISIC_0010847_segmentation.png

# %%
X = [] #skin cancer image
y = [] #mask of skin cancer

IMG_SIZE = 256 # size of image
height = 256
width = 256

def train_data(IMAGES, MASKS):
  '''
  function to store numpy array of train images
  input: images and corresponding ground truth response masks.
  '''
  # Images
  for img in sorted(IMAGES):
    img_arr=cv2.imread(img, cv2.IMREAD_GRAYSCALE)
    img_arr = cv2.resize(img_arr, (width, height))
    #img_arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)
            
    #gaussian blur
    img_arr = ndimage.gaussian_filter(img_arr, sigma=1)
            
    #contrast stretching
    f_max = (np.amax(img_arr))
    f_min = (np.amin(img_arr))
    img_arr = ((img_arr - f_min)/(f_max - f_min))*255
            
    #sharpen
    filter_blurred_f = ndimage.gaussian_filter(img_arr, sigma=1)
    alpha = 10
    img_arr = img_arr + alpha * (img_arr -filter_blurred_f)
            
    new_arr = img_arr/255.0
    X.append(new_arr)

  # Masks  
  for img in sorted(MASKS):
    truth_img_arr = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
    truth_new_arr = cv2.resize(truth_img_arr, (height, width))
    truth_new_arr = truth_new_arr/255.0
    y.append(truth_new_arr)


train_data(IMAGES, MASKS)


HEIGHT = 256
WIDTH = 256
X = np.array(X).reshape(-1, WIDTH, HEIGHT, 1)
y = np.array(y).reshape(-1, WIDTH, HEIGHT, 1)
print("Data Train shape: ", X.shape)
print("Data Train Mask", y.shape)

#save numpy array of train images mask
np.save('/content/drive/MyDrive/Reconnaissance-Formes/ISIC2018/Train/Train_img.npy', X)
np.save('/content/drive/MyDrive/Reconnaissance-Formes/ISIC2018/Train/Train_mask.npy', y)

# %% [markdown]
# ### Test data

# %%
X_test = []
DATA_TEST = "/content/drive/MyDrive/Reconnaissance-Formes/ISIC2018/Test"
def create_test_data(DATA_TEST):
    
    height = 256
    width = 256
    for img in os.listdir(DATA_TEST):
          img_arr=cv2.imread(os.path.join(DATA_TEST, img), cv2.IMREAD_GRAYSCALE)
          img_arr = cv2.resize(img_arr, (width, height))
            
          #gaussian blur
          img_arr = ndimage.gaussian_filter(img_arr, sigma=1)
            
          #contrast stretching
          f_max = (np.amax(img_arr))
          f_min = (np.amin(img_arr))
          img_arr = ((img_arr - f_min)/(f_max - f_min))*255
            
          #sharpen
          filter_blurred_f = ndimage.gaussian_filter(img_arr, 2)
          alpha = 10
          img_arr = img_arr + alpha * (img_arr -filter_blurred_f)
            
            
          new_arr = img_arr/255.0
          X_test.append(new_arr)

create_test_data(DATA_TEST)

# %%
height = 256
width = 256

X_test = np.array(X_test).reshape(-1, width, height, 1)
print(X_test.shape)

np.save('/content/drive/MyDrive/Reconnaissance-Formes/ISIC2018/Test_Skin.npy', X_test)
# Out:
# (1000, 256, 256, 1)

# %% [markdown]
# ## **Load Data saved**

# %%
# Train Images
X = np.load("/content/drive/MyDrive/Reconnaissance_Formes/ISIC2018/Train/Train_img.npy")

# Train Mask
y = np.load("/content/drive/MyDrive/Reconnaissance_Formes/ISIC2018/Train/Train_mask.npy")

# Test Images
X_test = np.load("/content/drive/MyDrive/Reconnaissance_Formes/ISIC2018/Test_Skin.npy")

# %% [markdown]
# ## **Split train and validation**

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size = 0.2, random_state = 123)

# %% [markdown]
# ### Check if training data looks all right

# %%
import random

ix = 0 #random.randint(0, len(X_train))
has_mask = y_train[ix].max() > 0

fig, ax = plt.subplots(1, 2, figsize=(15, 10))

ax[0].imshow(X_train[ix, ..., 0], cmap='Greys', interpolation='bilinear')
if has_mask:
    ax[0].contour(y_train[ix].squeeze(), colors='k', levels=[0.5])
ax[0].set_title('Melanoma')

ax[1].imshow(y_train[ix].squeeze(), interpolation='bilinear', cmap='gray')
ax[1].set_title('mask')
# Out:
# Text(0.5, 1.0, 'mask')

# %% [markdown]
# ## **Data Generator**
#
#
# > Nous organiserons notre ensemble de données sur disque afin de pouvoir utiliser la classe ImageDataGenerator de Keras pour générer des lots d'images à partir du disque sans avoir à conserver l'ensemble de données en mémoire.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

data_gen_args = dict(horizontal_flip = True, 
                     vertical_flip = True, 
                     rotation_range = 180, 
                     width_shift_range = 0.1, 
                     height_shift_range = 0.1)

image_datagen = ImageDataGenerator(**data_gen_args)
mask_datagen = ImageDataGenerator(**data_gen_args)

seed = 613 # Il est important d'utiliser la même graine pour les deux générateurs
bs = 16

image_generator = image_datagen.flow(X_train, seed=seed, batch_size=bs, shuffle=True)
mask_generator = mask_datagen.flow(y_train, seed=seed, batch_size=bs, shuffle=True)

# Just zip the two generators to get a generator that provides augmented images and masks at the same time
train_generator = zip(image_generator, mask_generator)

# %% [markdown]
# ## **Build model**

# %% [markdown]
# ### Modele 1
#
#
#
# > Dense prediction: Semantic image segmentation : Label each pixel of an image with a corresponding class of what is being represented.
#
# > pixel-level image classification.

# %%
IMG_HEIGHT = 256
IMG_WIDTH = 256
IMG_CHANNELS = 1

# %%
def unet(input_size = (IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)):
    inputs = Input(input_size)
    
    
    G=32
    
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    #3x3 matric on i'inputs' - 2 times
    bn1=GroupNormalization(groups=G)(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(bn1)
    #Pooling - 2x2 matrix applied on conv1

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    #3x3 matric on pooled data 
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    bn2=GroupNormalization(groups=G)(conv2)
    #3x3 matrix on convolution applied on pooled data
    pool2 = MaxPooling2D(pool_size=(2, 2))(bn2)
    #Pooling - 2x2 matrix applied on conv2
    
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    #3x3 matric on pooled data
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    bn3=GroupNormalization(groups=G)(conv3)
    #3x3 matrix on convolution applied on pooled data
    pool3 = MaxPooling2D(pool_size=(2, 2))(bn3)
    #Pooling - 2x2 matrix applied on conv3

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    bn4=GroupNormalization(groups=G)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(bn4)
    
    

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same', dilation_rate=1)(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same', dilation_rate=2)(conv5)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same', dilation_rate=4)(conv5)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same', dilation_rate=8)(conv5)


    bn5=GroupNormalization(groups=G)(conv5)
    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(bn5), bn4], axis=3)
    #up convulation aaplied on conv5 (512 pixels) which is to be superimposed with conv 4 (256 pixels) using 2x2 matrix
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    #3x3 matrix on up6 - convert to 256 pixels
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)
    bn6=GroupNormalization(groups=G)(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(bn6), bn3], axis=3)
    #up convulation aaplied on conv6 (256 pixels) which is to be superimposed with conv3 (128 pixels) 
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    #3x3 matrix on up6 - convert to 128 pixels
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)
    bn7=GroupNormalization(groups=G)(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(bn7), bn2], axis=3)
    #up convulation aaplied on conv7 (128 pixels) which is to be superimposed with conv2 (64 pixels)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    #3x3 matrix on up6 - convert to 64 pixels
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)
    bn8=GroupNormalization(groups=G)(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(bn8), bn1], axis=3)
    #up convulation aaplied on conv8 (64 pixels) which is to be superimposed with conv1 (32 pixels)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    #3x3 matrix on up6 - convert to 32 pixels
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)
    bn9=GroupNormalization(groups=G)(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(bn9)
    #conv9 converted to the image of original size under sigmoid activation by 1x1 matrix. The matrix is named conv10

    model = Model(inputs = inputs, outputs = conv10)
    
    return model

# %%
model = unet(input_size = (IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS))

# %% [markdown]
# ## **Metrics**
#
# > Jaccard distance
#
# > sensitivity
#
# > specificity

# %%
from keras import backend as K
import tensorflow as tf

# %%
def jaccard_distance(y_true, y_pred):
    """ Calculates mean of Jaccard distance as a loss function """
    intersection = tf.reduce_sum(y_true * y_pred, axis=(1,2))
    sum_ = tf.reduce_sum(y_true + y_pred, axis=(1,2))
    jac = (intersection) / (sum_ - intersection)
    return tf.reduce_mean(jac)


def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
model.compile(optimizer = Adam(lr = 1e-4), loss="binary_crossentropy", metrics = ['accuracy', jaccard_distance, sensitivity, specificity])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# group_normalization (GroupNorma (None, 256, 256, 32) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 32) 0           group_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 64) 18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 64) 36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# group_normalization_1 (GroupNor (None, 128, 128, 64) 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)   0           group_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 128)  147584      conv2d_4[0][0]
# __________________________________________________________________________________________________
# group_normalization_2 (GroupNor (None, 64, 64, 128)  256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0           group_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 256)  590080      conv2d_6[0][0]
# __________________________________________________________________________________________________
# group_normalization_3 (GroupNor (None, 32, 32, 256)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0           group_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 512)  2359808     conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 512)  2359808     conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 512)  2359808     conv2d_10[0][0]
# __________________________________________________________________________________________________
# group_normalization_4 (GroupNor (None, 16, 16, 512)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 256)  524544      group_normalization_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 512)  0           conv2d_transpose[0][0]
#                                                                  group_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_12[0][0]
# __________________________________________________________________________________________________
# group_normalization_5 (GroupNor (None, 32, 32, 256)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 128)  131200      group_normalization_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_1[0][0]
#                                                                  group_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_14[0][0]
# __________________________________________________________________________________________________
# group_normalization_6 (GroupNor (None, 64, 64, 128)  256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 64) 32832       group_normalization_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_2[0][0]
#                                                                  group_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_16[0][0]
# __________________________________________________________________________________________________
# group_normalization_7 (GroupNor (None, 128, 128, 64) 128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 32) 8224        group_normalization_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 64) 0           conv2d_transpose_3[0][0]
#                                                                  group_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_18[0][0]
# __________________________________________________________________________________________________
# group_normalization_8 (GroupNor (None, 256, 256, 32) 64          conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 1)  33          group_normalization_8[0][0]
# ==================================================================================================
# Total params: 12,482,081
# Trainable params: 12,482,081
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model_training_file.hdf5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
results = model.fit(X_train, y_train, batch_size=16, epochs=100, callbacks=callbacks,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/100
# 75/75 [==============================] - 91s 972ms/step - loss: 0.4280 - accuracy: 0.8124 - jaccard_distance: 0.2468 - sensitivity: 0.3520 - specificity: 0.9558 - val_loss: 0.2681 - val_accuracy: 0.8997 - val_jaccard_distance: 0.4928 - val_sensitivity: 0.6440 - val_specificity: 0.9896
#
# Epoch 00001: val_loss improved from inf to 0.26807, saving model to model_training_file.hdf5
# Epoch 2/100
# 75/75 [==============================] - 70s 938ms/step - loss: 0.2555 - accuracy: 0.9046 - jaccard_distance: 0.4569 - sensitivity: 0.6858 - specificity: 0.9690 - val_loss: 0.1941 - val_accuracy: 0.9251 - val_jaccard_distance: 0.5622 - val_sensitivity: 0.7714 - val_specificity: 0.9796
#
# Epoch 00002: val_loss improved from 0.26807 to 0.19411, saving model to model_training_file.hdf5
# Epoch 3/100
# 75/75 [==============================] - 71s 941ms/step - loss: 0.2074 - accuracy: 0.9227 - jaccard_distance: 0.5391 - sensitivity: 0.7678 - specificity: 0.9723 - val_loss: 0.1797 - val_accuracy: 0.9276 - val_jaccard_distance: 0.5769 - val_sensitivity: 0.8053 - val_specificity: 0.9720
#
# Epoch 00003: val_loss improved from 0.19411 to 0.17972, saving model to model_training_file.hdf5
# Epoch 4/100
# 75/75 [==============================] - 71s 943ms/step - loss: 0.1634 - accuracy: 0.9367 - jaccard_distance: 0.5894 - sensitivity: 0.8163 - specificity: 0.9732 - val_loss: 0.1801 - val_accuracy: 0.9279 - val_jaccard_distance: 0.6026 - val_sensitivity: 0.7750 - val_specificity: 0.9821
#
# Epoch 00004: val_loss did not improve from 0.17972
# Epoch 5/100
# 75/75 [==============================] - 71s 942ms/step - loss: 0.1603 - accuracy: 0.9364 - jaccard_distance: 0.5839 - sensitivity: 0.8080 - specificity: 0.9744 - val_loss: 0.1825 - val_accuracy: 0.9301 - val_jaccard_distance: 0.6113 - val_sensitivity: 0.7605 - val_specificity: 0.9883
#
# Epoch 00005: val_loss did not improve from 0.17972
# Epoch 6/100
# 75/75 [==============================] - 71s 942ms/step - loss: 0.1519 - accuracy: 0.9422 - jaccard_distance: 0.6308 - sensitivity: 0.8343 - specificity: 0.9763 - val_loss: 0.1896 - val_accuracy: 0.9298 - val_jaccard_distance: 0.5336 - val_sensitivity: 0.8368 - val_specificity: 0.9639
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00006: val_loss did not improve from 0.17972
# Epoch 7/100
# 75/75 [==============================] - 70s 939ms/step - loss: 0.1567 - accuracy: 0.9383 - jaccard_distance: 0.5746 - sensitivity: 0.8104 - specificity: 0.9784 - val_loss: 0.1600 - val_accuracy: 0.9366 - val_jaccard_distance: 0.6365 - val_sensitivity: 0.8457 - val_specificity: 0.9690
#
# Epoch 00007: val_loss improved from 0.17972 to 0.16000, saving model to model_training_file.hdf5
# Epoch 8/100
# 75/75 [==============================] - 71s 940ms/step - loss: 0.1321 - accuracy: 0.9469 - jaccard_distance: 0.6384 - sensitivity: 0.8498 - specificity: 0.9756 - val_loss: 0.1574 - val_accuracy: 0.9384 - val_jaccard_distance: 0.6566 - val_sensitivity: 0.8478 - val_specificity: 0.9701
#
# Epoch 00008: val_loss improved from 0.16000 to 0.15741, saving model to model_training_file.hdf5
# Epoch 9/100
# 75/75 [==============================] - 70s 939ms/step - loss: 0.1199 - accuracy: 0.9512 - jaccard_distance: 0.6674 - sensitivity: 0.8641 - specificity: 0.9766 - val_loss: 0.1546 - val_accuracy: 0.9401 - val_jaccard_distance: 0.6615 - val_sensitivity: 0.8577 - val_specificity: 0.9687
#
# Epoch 00009: val_loss improved from 0.15741 to 0.15464, saving model to model_training_file.hdf5
# Epoch 10/100
# 75/75 [==============================] - 70s 940ms/step - loss: 0.1178 - accuracy: 0.9526 - jaccard_distance: 0.6805 - sensitivity: 0.8781 - specificity: 0.9760 - val_loss: 0.1537 - val_accuracy: 0.9406 - val_jaccard_distance: 0.6722 - val_sensitivity: 0.8629 - val_specificity: 0.9679
#
# Epoch 00010: val_loss improved from 0.15464 to 0.15371, saving model to model_training_file.hdf5
# Epoch 11/100
# 75/75 [==============================] - 71s 940ms/step - loss: 0.1114 - accuracy: 0.9548 - jaccard_distance: 0.6889 - sensitivity: 0.8808 - specificity: 0.9771 - val_loss: 0.1577 - val_accuracy: 0.9403 - val_jaccard_distance: 0.6756 - val_sensitivity: 0.8424 - val_specificity: 0.9741
#
# Epoch 00011: val_loss did not improve from 0.15371
# Epoch 12/100
# 75/75 [==============================] - 71s 941ms/step - loss: 0.1100 - accuracy: 0.9559 - jaccard_distance: 0.6951 - sensitivity: 0.8819 - specificity: 0.9792 - val_loss: 0.1519 - val_accuracy: 0.9414 - val_jaccard_distance: 0.6877 - val_sensitivity: 0.8796 - val_specificity: 0.9632
#
# Epoch 00012: val_loss improved from 0.15371 to 0.15191, saving model to model_training_file.hdf5
# Epoch 13/100
# 75/75 [==============================] - 70s 940ms/step - loss: 0.1025 - accuracy: 0.9585 - jaccard_distance: 0.7072 - sensitivity: 0.8894 - specificity: 0.9791 - val_loss: 0.1556 - val_accuracy: 0.9411 - val_jaccard_distance: 0.6871 - val_sensitivity: 0.8664 - val_specificity: 0.9674
#
# Epoch 00013: val_loss did not improve from 0.15191
# Epoch 14/100
# 75/75 [==============================] - 71s 941ms/step - loss: 0.1015 - accuracy: 0.9590 - jaccard_distance: 0.7065 - sensitivity: 0.8862 - specificity: 0.9809 - val_loss: 0.1513 - val_accuracy: 0.9430 - val_jaccard_distance: 0.6980 - val_sensitivity: 0.8686 - val_specificity: 0.9692
#
# Epoch 00014: val_loss improved from 0.15191 to 0.15130, saving model to model_training_file.hdf5
# Epoch 15/100
# 75/75 [==============================] - 71s 940ms/step - loss: 0.0868 - accuracy: 0.9645 - jaccard_distance: 0.7130 - sensitivity: 0.9040 - specificity: 0.9815 - val_loss: 0.1498 - val_accuracy: 0.9447 - val_jaccard_distance: 0.7058 - val_sensitivity: 0.8617 - val_specificity: 0.9739
#
# Epoch 00015: val_loss improved from 0.15130 to 0.14985, saving model to model_training_file.hdf5
# Epoch 16/100
# 75/75 [==============================] - 71s 941ms/step - loss: 0.0945 - accuracy: 0.9624 - jaccard_distance: 0.7204 - sensitivity: 0.8976 - specificity: 0.9811 - val_loss: 0.1522 - val_accuracy: 0.9436 - val_jaccard_distance: 0.7082 - val_sensitivity: 0.8756 - val_specificity: 0.9676
#
# Epoch 00016: val_loss did not improve from 0.14985
# Epoch 17/100
# 75/75 [==============================] - 71s 941ms/step - loss: 0.0848 - accuracy: 0.9653 - jaccard_distance: 0.7334 - sensitivity: 0.9090 - specificity: 0.9812 - val_loss: 0.1503 - val_accuracy: 0.9441 - val_jaccard_distance: 0.7076 - val_sensitivity: 0.8837 - val_specificity: 0.9651
#
# Epoch 00017: val_loss did not improve from 0.14985
# Epoch 18/100
# 75/75 [==============================] - 71s 942ms/step - loss: 0.0813 - accuracy: 0.9672 - jaccard_distance: 0.7363 - sensitivity: 0.9125 - specificity: 0.9828 - val_loss: 0.1470 - val_accuracy: 0.9461 - val_jaccard_distance: 0.7200 - val_sensitivity: 0.8784 - val_specificity: 0.9699
#
# Epoch 00018: val_loss improved from 0.14985 to 0.14699, saving model to model_training_file.hdf5
# Epoch 19/100
# 75/75 [==============================] - 70s 940ms/step - loss: 0.0776 - accuracy: 0.9682 - jaccard_distance: 0.7513 - sensitivity: 0.9127 - specificity: 0.9842 - val_loss: 0.1528 - val_accuracy: 0.9455 - val_jaccard_distance: 0.7238 - val_sensitivity: 0.8714 - val_specificity: 0.9716
#
# Epoch 00019: val_loss did not improve from 0.14699
# Epoch 20/100
# 75/75 [==============================] - 71s 941ms/step - loss: 0.0759 - accuracy: 0.9685 - jaccard_distance: 0.7594 - sensitivity: 0.9167 - specificity: 0.9836 - val_loss: 0.1571 - val_accuracy: 0.9448 - val_jaccard_distance: 0.7245 - val_sensitivity: 0.8593 - val_specificity: 0.9746
#
# Epoch 00020: val_loss did not improve from 0.14699
# Epoch 21/100
# 75/75 [==============================] - 70s 940ms/step - loss: 0.0735 - accuracy: 0.9697 - jaccard_distance: 0.7681 - sensitivity: 0.9247 - specificity: 0.9837 - val_loss: 0.1524 - val_accuracy: 0.9456 - val_jaccard_distance: 0.7280 - val_sensitivity: 0.8907 - val_specificity: 0.9653
#
# Epoch 00021: val_loss did not improve from 0.14699
# Epoch 22/100
# 75/75 [==============================] - 71s 942ms/step - loss: 0.0664 - accuracy: 0.9725 - jaccard_distance: 0.7712 - sensitivity: 0.9325 - specificity: 0.9840 - val_loss: 0.1557 - val_accuracy: 0.9457 - val_jaccard_distance: 0.7329 - val_sensitivity: 0.8829 - val_specificity: 0.9680
#
# Epoch 00022: val_loss did not improve from 0.14699
# Epoch 23/100
# 75/75 [==============================] - 70s 941ms/step - loss: 0.0670 - accuracy: 0.9724 - jaccard_distance: 0.7874 - sensitivity: 0.9341 - specificity: 0.9847 - val_loss: 0.1589 - val_accuracy: 0.9460 - val_jaccard_distance: 0.7370 - val_sensitivity: 0.8737 - val_specificity: 0.9713
#
# Epoch 00023: val_loss did not improve from 0.14699
# Epoch 24/100
# 75/75 [==============================] - 71s 941ms/step - loss: 0.0602 - accuracy: 0.9751 - jaccard_distance: 0.7886 - sensitivity: 0.9361 - specificity: 0.9865 - val_loss: 0.1649 - val_accuracy: 0.9452 - val_jaccard_distance: 0.7369 - val_sensitivity: 0.8636 - val_specificity: 0.9743
#
# Epoch 00024: val_loss did not improve from 0.14699
# Epoch 25/100
# 75/75 [==============================] - 70s 941ms/step - loss: 0.0573 - accuracy: 0.9762 - jaccard_distance: 0.7935 - sensitivity: 0.9382 - specificity: 0.9874 - val_loss: 0.1759 - val_accuracy: 0.9427 - val_jaccard_distance: 0.7359 - val_sensitivity: 0.8523 - val_specificity: 0.9744
#
# Epoch 00025: val_loss did not improve from 0.14699
# Epoch 26/100
# 75/75 [==============================] - 71s 941ms/step - loss: 0.0555 - accuracy: 0.9770 - jaccard_distance: 0.8025 - sensitivity: 0.9394 - specificity: 0.9879 - val_loss: 0.1744 - val_accuracy: 0.9441 - val_jaccard_distance: 0.7385 - val_sensitivity: 0.8418 - val_specificity: 0.9794
#
# Epoch 00026: val_loss did not improve from 0.14699
# Epoch 27/100
# 75/75 [==============================] - 70s 940ms/step - loss: 0.0492 - accuracy: 0.9793 - jaccard_distance: 0.8080 - sensitivity: 0.9413 - specificity: 0.9895 - val_loss: 0.1690 - val_accuracy: 0.9447 - val_jaccard_distance: 0.7438 - val_sensitivity: 0.8960 - val_specificity: 0.9620
#
# Epoch 00027: val_loss did not improve from 0.14699
# Epoch 28/100
# 75/75 [==============================] - 70s 941ms/step - loss: 0.0523 - accuracy: 0.9782 - jaccard_distance: 0.8181 - sensitivity: 0.9508 - specificity: 0.9875 - val_loss: 0.1799 - val_accuracy: 0.9440 - val_jaccard_distance: 0.7453 - val_sensitivity: 0.8634 - val_specificity: 0.9723
#
# Epoch 00028: val_loss did not improve from 0.14699
# Epoch 00028: early stopping

# %% [markdown]
# ## **Results : Learning curve**

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend()

# %% [markdown]
# ## **Load best model**

# %%
model.load_weights('model_training_file.hdf5')

# %% [markdown]
# ## **Model testing and visualization**

# %%
# Make prediction 
selecting_index = 200
prediction_input = np.expand_dims(X_valid[selecting_index], axis=0) # testing input
# Model predict
predict_img = model.predict(prediction_input)

# Note:: Keras model will predict output with shape of n x height x width x channel
print('Predicted mask shape:: ', predict_img.shape)

fig, axs = plt.subplots(1,3, figsize=(12,7))
axs[0].imshow(np.squeeze(predict_img))
axs[0].axis('off')
axs[0].set_title('Predicted Segmentation')
axs[1].imshow(np.squeeze(X_valid[selecting_index]))
axs[1].axis('off')
axs[1].set_title('Input Image')
axs[2].imshow(np.squeeze(y_valid[selecting_index]))
axs[2].axis('off')
axs[2].set_title('Target Truth')
# Out:
# Predicted mask shape::  (1, 256, 256, 1)
# Text(0.5, 1.0, 'Target Truth')

# %% [markdown]
# ## **Evaluate on validation set**

# %%
model.evaluate(X_valid, y_valid, verbose=1)
# Out:
# 10/10 [==============================] - 9s 416ms/step - loss: 0.1470 - accuracy: 0.9461 - jaccard_distance: 0.7231 - sensitivity: 0.8783 - specificity: 0.9704
# [0.14698536694049835,
#  0.9461104273796082,
#  0.7231217622756958,
#  0.8783115148544312,
#  0.9703859090805054]

# %% [markdown]
# ## **Prediction on Train, Validation, Test set**

# %%
preds_train = model.predict(X_train, verbose=1)
preds_val = model.predict(X_valid, verbose=1)


# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
# Out:
# 38/38 [==============================] - 17s 445ms/step
# 10/10 [==============================] - 4s 458ms/step

# %%
def plot_sample(X, y, preds, binary_preds, ix=None):
    if ix is None:
        ix = random.randint(0, len(X))

    has_mask = y[ix].max() > 0

    fig, ax = plt.subplots(1, 4, figsize=(20, 10))
    ax[0].imshow(X[ix, ..., 0], cmap='Greys')
    if has_mask:
        ax[0].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[0].set_title('Melanoma')

    ax[1].imshow(y[ix].squeeze())
    ax[1].set_title('Tumor')

    ax[2].imshow(preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[2].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[2].set_title('Tumor Predicted')
    
    ax[3].imshow(binary_preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[3].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[3].set_title('Tumor Predicted binary')

# %% [markdown]
# ### **Prediction on Train set**

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t, ix=40)

# %% [markdown]
# ### **Prediction on Validation set**

# %%
plot_sample(X_valid, y_valid, preds_val, preds_val_t, ix=200)

# %% [markdown]
# ### **Prediction on Test set**

# %%
eval_segm = model.predict(X_test,batch_size=16,verbose=1)
# Out:
# 63/63 [==============================] - 14s 154ms/step

# %%
# Threshold predictions
preds_test_t = (eval_segm > 0.5).astype(np.uint8)

# %%
def plot_test(X_test, preds, binary_preds, ix=None):
    if ix is None:
        ix = random.randint(0, len(X_test))


    fig, ax = plt.subplots(1, 3, figsize=(20, 10))
    ax[0].imshow(X_test[ix, ..., 0], cmap='Greys')
    ax[0].set_title('Test Image')

    ax[1].imshow(preds[ix].squeeze(), vmin=0, vmax=1)
    ax[1].set_title('Tumor Predicted')
    
    ax[2].imshow(binary_preds[ix].squeeze(), vmin=0, vmax=1)
    ax[2].set_title('Tumor Predicted binary')

# %%
plot_test(X_test, eval_segm, preds_test_t, ix=2)
